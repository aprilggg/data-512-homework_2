# %% [markdown]
# # Considering Bias in Data
#
# The objective of this assignment is to delve into the concept of bias in data through an exploration of Wikipedia articles. The analysis will primarily focus on articles about cities across various states in the United States. By combining a dataset of Wikipedia articles with state populations, we will leverage the ORES machine learning service to estimate the quality of these city-related articles.
#
# The following notebook outlines the sequential data processing steps for this analysis.

# %% [markdown]
# ## Step 1: Getting the Article, Population and Region Data

# %%
# import 

import json, time, urllib.parse
import requests
import csv
import pandas as pd

# %%
#########
#
#    CONSTANTS -setting up API parameter template
#

# The basic English Wikipedia API endpoint
API_ENWIKIPEDIA_ENDPOINT = "https://en.wikipedia.org/w/api.php"

# We'll assume that there needs to be some throttling for these requests - we should always be nice to a free data resource
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED

REQUEST_HEADERS = {
    'User-Agent': '<april.gg@uw.edu>, University of Washington, MSDS DATA 512 - AUTUMN 2023',
}

# Creating a list with all Oscar-winning movies title from local csv file
ARTICLE_TITLES = []

TITLE_FILE = 'C:/Users/april/Documents/Documents/MSDS/DATA512/HW2/us_cities_by_state_SEPT.2023.csv'

with open(TITLE_FILE, newline='', encoding='utf-8') as file:
    reader = csv.reader(file)
    for row in reader:
        if row:  
            ARTICLE_TITLES.append(row[1])


PAGEINFO_EXTENDED_PROPERTIES = ""

PAGEINFO_PARAMS_TEMPLATE = {
    "action": "query",
    "format": "json",
    "titles": "",           
    "prop": "info",
    "inprop": PAGEINFO_EXTENDED_PROPERTIES
}

# %% [markdown]
# The subsequent functions serve the purpose of requesting revision IDs from the Wikipedia API, utilizing the titles extracted from a local CSV file. The retrieved output will be integrated back into the original file.

# %%
def request_pageinfo_per_article(article_title=None,
                                 endpoint_url=API_ENWIKIPEDIA_ENDPOINT,
                                 request_template=PAGEINFO_PARAMS_TEMPLATE,
                                 headers=REQUEST_HEADERS):

    # article title can be as a parameter to the call or in the request_template
    if article_title:
        request_template['titles'] = article_title

    if not request_template['titles']:
        raise Exception("Must supply an article title to make a pageinfo request.")

    # make the request
    try:

        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(endpoint_url, headers=headers, params=request_template)
        json_response = response.json()

        pages = json_response.get('query', {}).get('pages', {})
        for page_id in pages:
            page_info = pages[page_id]
            article_name = page_info.get('title', '')
            revid = page_info.get('lastrevid', '')
            article_info.append([article_name, revid])
            update_csv_with_revid(article_name, revid)
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# Creating function to add revid infomation to the existing file
def update_csv_with_revid(article_name, revid):
    df = pd.read_csv(TITLE_FILE)
    if 'revid' not in df.columns:
        df['revid'] = ''
    df.loc[df['page_title'] == article_name, 'revid'] = int(revid)
    df.to_csv(TITLE_FILE, index=False, mode='w')


if __name__ == '__main__':
    article_info = []
    for title in ARTICLE_TITLES: 
        response = request_pageinfo_per_article(title)
        if response:
            print(f"Retrieved info for {title}")
# Out:
# invalid literal for int() with base 10: ''
# Retrieved info for Abbeville, Alabama
# Retrieved info for Adamsville, Alabama
# Retrieved info for Addison, Alabama
# Retrieved info for Akron, Alabama
# Retrieved info for Alabaster, Alabama
# Retrieved info for Albertville, Alabama
# Retrieved info for Alexander City, Alabama
# Retrieved info for Aliceville, Alabama
# Retrieved info for Allgood, Alabama
# Retrieved info for Altoona, Alabama
# Retrieved info for Andalusia, Alabama
# Retrieved info for Anderson, Lauderdale County, Alabama
# Retrieved info for Anniston, Alabama
# Retrieved info for Arab, Alabama
# Retrieved info for Ardmore, Alabama
# Retrieved info for Argo, Alabama
# Retrieved info for Ariton, Alabama
# Retrieved info for Arley, Alabama
# Retrieved info for Ashford, Alabama
# Retrieved info for Ashland, Alabama
# Retrieved info for Ashville, Alabama
# Retrieved info for Athens, Alabama
# Retrieved info for Atmore, Alabama
# Retrieved info for Attalla, Alabama
# Retrieved info for Auburn, Alabama
# Retrieved info for Autaugaville, Alabama
# Retrieved info for Avon, Alabama
# Retrieved info for Babbie, Alabama
# Retrieved info for Baileyton, Alabama
# Retrieved info for Bakerhill, Alabama
# Retrieved info for Banks, Alabama
# Retrieved info for Bay Minette, Alabama
# Retrieved info for Bayou La Batre, Alabama
# Retrieved info for Bear Creek, Alabama
# Retrieved info for Beatrice, Alabama
# Retrieved info for Beaverton, Alabama
# Retrieved info for Belk, Alabama
# Retrieved info for Benton, Alabama
# Retrieved info for Berlin, Alabama
# Retrieved info for Berry, Alabama
# Retrieved info for Bessemer, Alabama
# Retrieved info for Billingsley, Alabama
# Retrieved info for Birmingham, Alabama
# Retrieved info for Black, Alabama
# Retrieved info for Blountsville, Alabama
# Retrieved info for Blue Springs, Alabama
# Retrieved info for Boaz, Alabama
# Retrieved info for Boligee, Alabama
# Retrieved info for Bon Air, Alabama
# Retrieved info for Brantley, Alabama
# Retrieved info for Brent, Alabama
# Retrieved info for Brewton, Alabama
# Retrieved info for Bridgeport, Alabama
# Retrieved info for Brighton, Alabama
# Retrieved info for Brilliant, Alabama
# Retrieved info for Brookside, Alabama
# Retrieved info for Brookwood, Alabama
# Retrieved info for Brundidge, Alabama
# Retrieved info for Butler, Alabama
# Retrieved info for Calera, Alabama
# Retrieved info for Camden, Alabama
# Retrieved info for Camp Hill, Alabama
# Retrieved info for Carbon Hill, Alabama
# Retrieved info for Cardiff, Alabama
# Retrieved info for Carolina, Alabama
# Retrieved info for Carrollton, Alabama
# Retrieved info for Castleberry, Alabama
# Retrieved info for Cedar Bluff, Alabama
# Retrieved info for Center Point, Alabama
# Retrieved info for Centre, Alabama
# Retrieved info for Centreville, Alabama
# Retrieved info for Chatom, Alabama
# Retrieved info for Chelsea, Alabama
# Retrieved info for Cherokee, Alabama
# Retrieved info for Chickasaw, Alabama
# Retrieved info for Childersburg, Alabama
# Retrieved info for Citronelle, Alabama
# Retrieved info for Clanton, Alabama
# Retrieved info for Clay, Alabama
# Retrieved info for Clayhatchee, Alabama
# Retrieved info for Clayton, Alabama
# Retrieved info for Cleveland, Alabama
# Retrieved info for Clio, Alabama
# Retrieved info for Coaling, Alabama
# Retrieved info for Coffee Springs, Alabama
# Retrieved info for Coffeeville, Alabama
# Retrieved info for Coker, Alabama
# Retrieved info for Collinsville, Alabama
# Retrieved info for Colony, Alabama
# Retrieved info for Columbia, Alabama
# Retrieved info for Columbiana, Alabama
# Retrieved info for Coosada, Alabama
# Retrieved info for Cordova, Alabama
# Retrieved info for Cottonwood, Alabama
# Retrieved info for County Line, Alabama
# Retrieved info for Courtland, Alabama
# Retrieved info for Cowarts, Alabama
# Retrieved info for Creola, Alabama
# Retrieved info for Crossville, Alabama
# Retrieved info for Cuba, Alabama
# Retrieved info for Cullman, Alabama
# Retrieved info for Cusseta, Alabama
# Retrieved info for Dadeville, Alabama
# Retrieved info for Daleville, Alabama
# Retrieved info for Daphne, Alabama
# Retrieved info for Dauphin Island, Alabama
# Retrieved info for Daviston, Alabama
# Retrieved info for Dayton, Alabama
# Retrieved info for Deatsville, Alabama
# Retrieved info for Decatur, Alabama
# Retrieved info for Demopolis, Alabama
# Retrieved info for Detroit, Alabama
# Retrieved info for Dodge City, Alabama
# Retrieved info for Dora, Alabama
# Retrieved info for Dothan, Alabama
# Retrieved info for Double Springs, Alabama
# Retrieved info for Douglas, Alabama
# Retrieved info for Dozier, Alabama
# Retrieved info for Dutton, Alabama
# Retrieved info for East Brewton, Alabama
# Retrieved info for Eclectic, Alabama
# Retrieved info for Edwardsville, Alabama
# Retrieved info for Elba, Alabama
# Retrieved info for Elberta, Alabama
# Retrieved info for Eldridge, Alabama
# Retrieved info for Elkmont, Alabama
# Retrieved info for Elmore, Alabama
# Retrieved info for Emelle, Alabama
# Retrieved info for Enterprise, Alabama
# Retrieved info for Epes, Alabama
# Retrieved info for Ethelsville, Alabama
# Retrieved info for Eufaula, Alabama
# Retrieved info for Eutaw, Alabama
# Retrieved info for Eva, Alabama
# Retrieved info for Evergreen, Conecuh County, Alabama
# Retrieved info for Excel, Alabama
# Retrieved info for Fairfield, Alabama
# Retrieved info for Fairhope, Alabama
# Retrieved info for Fairview, Alabama
# Retrieved info for Falkville, Alabama
# Retrieved info for Faunsdale, Alabama
# Retrieved info for Fayette, Alabama
# Retrieved info for Five Points, Alabama
# Retrieved info for Flomaton, Alabama
# Retrieved info for Florala, Alabama
# Retrieved info for Florence, Alabama
# Retrieved info for Foley, Alabama
# Retrieved info for Forkland, Alabama
# Retrieved info for Fort Deposit, Alabama
# Retrieved info for Fort Payne, Alabama
# Retrieved info for Franklin, Alabama
# Retrieved info for Frisco City, Alabama
# Retrieved info for Fruithurst, Alabama
# Retrieved info for Fulton, Alabama
# Retrieved info for Fultondale, Alabama
# Retrieved info for Fyffe, Alabama
# Retrieved info for Gadsden, Alabama
# Retrieved info for Gainesville, Alabama
# Retrieved info for Gantt, Alabama
# Retrieved info for Garden City, Alabama
# Retrieved info for Gardendale, Alabama
# Retrieved info for Gaylesville, Alabama
# Retrieved info for Geiger, Alabama
# Retrieved info for Geneva, Alabama
# Retrieved info for Georgiana, Alabama
# Retrieved info for Geraldine, Alabama
# Retrieved info for Gilbertown, Alabama
# Retrieved info for Glen Allen, Alabama
# Retrieved info for Glencoe, Alabama
# Retrieved info for Glenwood, Alabama
# Retrieved info for Goldville, Alabama
# Retrieved info for Good Hope, Alabama
# Retrieved info for Goodwater, Alabama
# Retrieved info for Gordo, Alabama
# Retrieved info for Gordon, Alabama
# Retrieved info for Gordonville, Alabama
# Retrieved info for Goshen, Alabama
# Retrieved info for Grant, Alabama
# Retrieved info for Graysville, Alabama
# Retrieved info for Greensboro, Alabama
# Retrieved info for Greenville, Alabama
# Retrieved info for Grimes, Alabama
# Retrieved info for Grove Hill, Alabama
# Retrieved info for Guin, Alabama
# Retrieved info for Gulf Shores, Alabama
# Retrieved info for Guntersville, Alabama
# Retrieved info for Gurley, Alabama
# Retrieved info for Gu-Win, Alabama
# Retrieved info for Hackleburg, Alabama
# Retrieved info for Haleburg, Alabama
# Retrieved info for Haleyville, Alabama
# Retrieved info for Hamilton, Alabama
# Retrieved info for Hammondville, Alabama
# Retrieved info for Hanceville, Alabama
# Retrieved info for Harpersville, Alabama
# Retrieved info for Hartford, Alabama
# Retrieved info for Hartselle, Alabama
# Retrieved info for Hayden, Alabama
# Retrieved info for Hayneville, Alabama
# Retrieved info for Headland, Alabama
# Retrieved info for Heath, Alabama
# Retrieved info for Heflin, Alabama
# Retrieved info for Helena, Alabama
# Retrieved info for Henagar, Alabama
# Retrieved info for Highland Lake, Alabama
# Retrieved info for Hillsboro, Alabama
# Retrieved info for Hobson City, Alabama
# Retrieved info for Hodges, Alabama
# Retrieved info for Hokes Bluff, Alabama
# Retrieved info for Holly Pond, Alabama
# Retrieved info for Hollywood, Alabama
# Retrieved info for Homewood, Alabama
# Retrieved info for Hoover, Alabama
# Retrieved info for Horn Hill, Alabama
# Retrieved info for Hueytown, Alabama
# Retrieved info for Huntsville, Alabama
# Retrieved info for Hurtsboro, Alabama
# Retrieved info for Hytop, Alabama
# Retrieved info for Ider, Alabama
# Retrieved info for Indian Springs Village, Alabama
# Retrieved info for Irondale, Alabama
# Retrieved info for Jackson, Alabama
# Retrieved info for Jackson's Gap, Alabama
# Retrieved info for Jacksonville, Alabama
# Retrieved info for Jasper, Alabama
# Retrieved info for Jemison, Alabama
# Retrieved info for Kansas, Alabama
# Retrieved info for Kellyton, Alabama
# Retrieved info for Kennedy, Alabama
# Retrieved info for Killen, Alabama
# Retrieved info for Kimberly, Alabama
# Retrieved info for Kinsey, Alabama
# Retrieved info for Kinston, Alabama
# Retrieved info for LaFayette, Alabama
# Retrieved info for Lake View, Alabama
# Retrieved info for Lakeview, Alabama
# Retrieved info for Lanett, Alabama
# Retrieved info for Langston, Alabama
# Retrieved info for Leeds, Alabama
# Retrieved info for Leesburg, Alabama
# Retrieved info for Leighton, Alabama
# Retrieved info for Lester, Alabama
# Retrieved info for Level Plains, Alabama
# Retrieved info for Lexington, Alabama
# Retrieved info for Libertyville, Alabama
# Retrieved info for Lincoln, Alabama
# Retrieved info for Linden, Alabama
# Retrieved info for Lineville, Alabama
# Retrieved info for Lipscomb, Alabama
# Retrieved info for Lisman, Alabama
# Retrieved info for Littleville, Alabama
# Retrieved info for Livingston, Alabama
# Retrieved info for Loachapoka, Alabama
# Retrieved info for Lockhart, Alabama
# Retrieved info for Locust Fork, Alabama
# Retrieved info for Louisville, Alabama
# Retrieved info for Lowndesboro, Alabama
# Retrieved info for Loxley, Alabama
# Retrieved info for Luverne, Alabama
# Retrieved info for Lynn, Alabama
# Retrieved info for Madison, Alabama
# Retrieved info for Madrid, Alabama
# Retrieved info for Magnolia Springs, Alabama
# Retrieved info for Malvern, Alabama
# Retrieved info for Maplesville, Alabama
# Retrieved info for Margaret, Alabama
# Retrieved info for Marion, Alabama
# Retrieved info for Maytown, Alabama
# Retrieved info for McIntosh, Alabama
# Retrieved info for McKenzie, Alabama
# Retrieved info for McMullen, Alabama
# Retrieved info for Memphis, Alabama
# Retrieved info for Mentone, Alabama
# Retrieved info for Midfield, Alabama
# Retrieved info for Midland City, Alabama
# Retrieved info for Midway, Alabama
# Retrieved info for Millbrook, Alabama
# Retrieved info for Millport, Alabama
# Retrieved info for Millry, Alabama
# Retrieved info for Mobile, Alabama
# Retrieved info for Monroeville, Alabama
# Retrieved info for Montevallo, Alabama
# Retrieved info for Montgomery, Alabama
# Retrieved info for Moody, Alabama
# Retrieved info for Mooresville, Alabama
# Retrieved info for Morris, Alabama
# Retrieved info for Mosses, Alabama
# Retrieved info for Moulton, Alabama
# Retrieved info for Moundville, Alabama
# Retrieved info for Mount Vernon, Alabama
# Retrieved info for Mountain Brook, Alabama
# Retrieved info for Mulga, Alabama
# Retrieved info for Munford, Alabama
# Retrieved info for Muscle Shoals, Alabama
# Retrieved info for Myrtlewood, Alabama
# Retrieved info for Napier Field, Alabama
# Retrieved info for Natural Bridge, Alabama
# Retrieved info for Nauvoo, Alabama
# Retrieved info for Nectar, Alabama
# Retrieved info for Needham, Alabama
# Retrieved info for New Brockton, Alabama
# Retrieved info for New Hope, Alabama
# Retrieved info for New Site, Alabama
# Retrieved info for Newbern, Alabama
# Retrieved info for Newton, Alabama
# Retrieved info for Newville, Alabama
# Retrieved info for North Courtland, Alabama
# Retrieved info for North Johns, Alabama
# Retrieved info for Northport, Alabama
# Retrieved info for Notasulga, Alabama
# Retrieved info for Oak Grove, Alabama
# Retrieved info for Oak Hill, Alabama
# Retrieved info for Oakman, Alabama
# Retrieved info for Odenville, Alabama
# Retrieved info for Ohatchee, Alabama
# Retrieved info for Oneonta, Alabama
# Retrieved info for Onycha, Alabama
# Retrieved info for Opelika, Alabama
# Retrieved info for Opp, Alabama
# Retrieved info for Orange Beach, Alabama
# Retrieved info for Orrville, Alabama
# Retrieved info for Owens Cross Roads, Alabama
# Retrieved info for Oxford, Alabama
# Retrieved info for Ozark, Alabama
# Retrieved info for Paint Rock, Alabama
# Retrieved info for Parrish, Alabama
# Retrieved info for Pelham, Alabama
# Retrieved info for Pell City, Alabama
# Retrieved info for Pennington, Alabama
# Retrieved info for Perdido Beach, Alabama
# Retrieved info for Petrey, Alabama
# Retrieved info for Phenix City, Alabama
# Retrieved info for Phil Campbell, Alabama
# Retrieved info for Pickensville, Alabama
# Retrieved info for Piedmont, Alabama
# Retrieved info for Pike Road, Alabama
# Retrieved info for Pinckard, Alabama
# Retrieved info for Pine Apple, Alabama
# Retrieved info for Pine Hill, Alabama
# Retrieved info for Pine Ridge, Alabama
# Retrieved info for Pinson, Alabama
# Retrieved info for Pisgah, Alabama
# Retrieved info for Pleasant Grove, Alabama
# Retrieved info for Pleasant Groves, Alabama
# Retrieved info for Pollard, Alabama
# Retrieved info for Powell, Alabama
# Retrieved info for Prattville, Alabama
# Retrieved info for Priceville, Alabama
# Retrieved info for Prichard, Alabama
# Retrieved info for Providence, Alabama
# Retrieved info for Ragland, Alabama
# Retrieved info for Rainbow City, Alabama
# Retrieved info for Rainsville, Alabama
# Retrieved info for Ranburne, Alabama
# Retrieved info for Red Bay, Alabama
# Retrieved info for Red Level, Alabama
# Retrieved info for Reece City, Alabama
# Retrieved info for Reform, Alabama
# Retrieved info for Rehobeth, Alabama
# Retrieved info for Repton, Alabama
# Retrieved info for Ridgeville, Alabama
# Retrieved info for River Falls, Alabama
# Retrieved info for Riverside, Alabama
# Retrieved info for Riverview, Alabama
# Retrieved info for Roanoke, Alabama
# Retrieved info for Robertsdale, Alabama
# Retrieved info for Rockford, Alabama
# Retrieved info for Rogersville, Alabama
# Retrieved info for Rosa, Alabama
# Retrieved info for Russellville, Alabama
# Retrieved info for Rutledge, Alabama
# Retrieved info for St. Florian, Alabama
# Retrieved info for Samson, Alabama
# Retrieved info for Sand Rock, Alabama
# Retrieved info for Sanford, Alabama
# Retrieved info for Saraland, Alabama
# Retrieved info for Sardis City, Alabama
# Retrieved info for Satsuma, Alabama
# Retrieved info for Scottsboro, Alabama
# Retrieved info for Section, Alabama
# Retrieved info for Selma, Alabama
# Retrieved info for Sheffield, Alabama
# Retrieved info for Shiloh, DeKalb County, Alabama
# Retrieved info for Shorter, Alabama
# Retrieved info for Silas, Alabama
# Retrieved info for Silverhill, Alabama
# Retrieved info for Sipsey, Alabama
# Retrieved info for Skyline, Alabama
# Retrieved info for Slocomb, Alabama
# Retrieved info for Smiths Station, Alabama
# Retrieved info for Snead, Alabama
# Retrieved info for Somerville, Alabama
# Retrieved info for South Vinemont, Alabama
# Retrieved info for Southside, Alabama
# Retrieved info for Spanish Fort, Alabama
# Retrieved info for Springville, Alabama
# Retrieved info for Steele, Alabama
# Retrieved info for Stevenson, Alabama
# Retrieved info for Sulligent, Alabama
# Retrieved info for Sumiton, Alabama
# Retrieved info for Summerdale, Alabama
# Retrieved info for Susan Moore, Alabama
# Retrieved info for Sweet Water, Alabama
# Retrieved info for Sylacauga, Alabama
# Retrieved info for Sylvan Springs, Alabama
# Retrieved info for Sylvania, Alabama
# Retrieved info for Talladega Springs, Alabama
# Retrieved info for Talladega, Alabama
# Retrieved info for Tallassee, Alabama
# Retrieved info for Tarrant, Alabama
# Retrieved info for Taylor, Alabama
# Retrieved info for Thomaston, Alabama
# Retrieved info for Thomasville, Alabama
# Retrieved info for Thorsby, Alabama
# Retrieved info for Town Creek, Alabama
# Retrieved info for Toxey, Alabama
# Retrieved info for Trafford, Alabama
# Retrieved info for Triana, Alabama
# Retrieved info for Trinity, Alabama
# Retrieved info for Troy, Alabama
# Retrieved info for Trussville, Alabama
# Retrieved info for Tuscaloosa, Alabama
# Retrieved info for Tuscumbia, Alabama
# Retrieved info for Tuskegee, Alabama
# Retrieved info for Twin, Alabama
# Retrieved info for Union Grove, Alabama
# Retrieved info for Union Springs, Alabama
# Retrieved info for Union, Alabama
# Retrieved info for Uniontown, Alabama
# Retrieved info for Valley, Alabama
# Retrieved info for Valley Grande, Alabama
# Retrieved info for Valley Head, Alabama
# Retrieved info for Vance, Alabama
# Retrieved info for Vernon, Alabama
# Retrieved info for Vestavia Hills, Alabama
# Retrieved info for Vina, Alabama
# Retrieved info for Vincent, Alabama
# Retrieved info for Vredenburgh, Alabama
# Retrieved info for Wadley, Alabama
# Retrieved info for Waldo, Alabama
# Retrieved info for Walnut Grove, Alabama
# Retrieved info for Warrior, Alabama
# Retrieved info for Waterloo, Alabama
# Retrieved info for Waverly, Alabama
# Retrieved info for Weaver, Alabama
# Retrieved info for Webb, Alabama
# Retrieved info for Wedowee, Alabama
# Retrieved info for West Blocton, Alabama
# Retrieved info for West Jefferson, Alabama
# Retrieved info for West Point, Alabama
# Retrieved info for Westover, Alabama
# Retrieved info for Wetumpka, Alabama
# Retrieved info for White Hall, Alabama
# Retrieved info for Wilsonville, Alabama
# Retrieved info for Wilton, Alabama
# Retrieved info for Winfield, Alabama
# Retrieved info for Woodland, Alabama
# Retrieved info for Woodstock, Alabama
# Retrieved info for Woodville, Alabama
# Retrieved info for Yellow Bluff, Alabama
# Retrieved info for York, Alabama
# Retrieved info for Abbeville, Alabama
# Retrieved info for Adamsville, Alabama
# Retrieved info for Addison, Alabama
# Retrieved info for Akron, Alabama
# Retrieved info for Alabaster, Alabama
# Retrieved info for Albertville, Alabama
# Retrieved info for Alexander City, Alabama
# Retrieved info for Aliceville, Alabama
# Retrieved info for Allgood, Alabama
# Retrieved info for Altoona, Alabama
# Retrieved info for Andalusia, Alabama
# Retrieved info for Anderson, Lauderdale County, Alabama
# Retrieved info for Anniston, Alabama
# Retrieved info for Arab, Alabama
# Retrieved info for Ardmore, Alabama
# Retrieved info for Argo, Alabama
# Retrieved info for Ariton, Alabama
# Retrieved info for Arley, Alabama
# Retrieved info for Ashford, Alabama
# Retrieved info for Ashland, Alabama
# Retrieved info for Ashville, Alabama
# Retrieved info for Athens, Alabama
# Retrieved info for Atmore, Alabama
# Retrieved info for Attalla, Alabama
# Retrieved info for Auburn, Alabama
# Retrieved info for Autaugaville, Alabama
# Retrieved info for Avon, Alabama
# Retrieved info for Babbie, Alabama
# Retrieved info for Baileyton, Alabama
# Retrieved info for Bakerhill, Alabama
# Retrieved info for Banks, Alabama
# Retrieved info for Bay Minette, Alabama
# Retrieved info for Bayou La Batre, Alabama
# Retrieved info for Bear Creek, Alabama
# Retrieved info for Beatrice, Alabama
# Retrieved info for Beaverton, Alabama
# Retrieved info for Belk, Alabama
# Retrieved info for Benton, Alabama
# Retrieved info for Berlin, Alabama
# Retrieved info for Berry, Alabama
# Retrieved info for Bessemer, Alabama
# Retrieved info for Billingsley, Alabama
# Retrieved info for Birmingham, Alabama
# Retrieved info for Black, Alabama
# Retrieved info for Blountsville, Alabama
# Retrieved info for Blue Springs, Alabama
# Retrieved info for Boaz, Alabama
# Retrieved info for Boligee, Alabama
# Retrieved info for Bon Air, Alabama
# Retrieved info for Brantley, Alabama
# Retrieved info for Brent, Alabama
# Retrieved info for Brewton, Alabama
# Retrieved info for Bridgeport, Alabama
# Retrieved info for Brighton, Alabama
# Retrieved info for Brilliant, Alabama
# Retrieved info for Brookside, Alabama
# Retrieved info for Brookwood, Alabama
# Retrieved info for Brundidge, Alabama
# Retrieved info for Butler, Alabama
# Retrieved info for Calera, Alabama
# Retrieved info for Camden, Alabama
# Retrieved info for Camp Hill, Alabama
# Retrieved info for Carbon Hill, Alabama
# Retrieved info for Cardiff, Alabama
# Retrieved info for Carolina, Alabama
# Retrieved info for Carrollton, Alabama
# Retrieved info for Castleberry, Alabama
# Retrieved info for Cedar Bluff, Alabama
# Retrieved info for Center Point, Alabama
# Retrieved info for Centre, Alabama
# Retrieved info for Centreville, Alabama
# Retrieved info for Chatom, Alabama
# Retrieved info for Chelsea, Alabama
# Retrieved info for Cherokee, Alabama
# Retrieved info for Chickasaw, Alabama
# Retrieved info for Childersburg, Alabama
# Retrieved info for Citronelle, Alabama
# Retrieved info for Clanton, Alabama
# Retrieved info for Clay, Alabama
# Retrieved info for Clayhatchee, Alabama
# Retrieved info for Clayton, Alabama
# Retrieved info for Cleveland, Alabama
# Retrieved info for Clio, Alabama
# Retrieved info for Coaling, Alabama
# Retrieved info for Coffee Springs, Alabama
# Retrieved info for Coffeeville, Alabama
# Retrieved info for Coker, Alabama
# Retrieved info for Collinsville, Alabama
# Retrieved info for Colony, Alabama
# Retrieved info for Columbia, Alabama
# Retrieved info for Columbiana, Alabama
# Retrieved info for Coosada, Alabama
# Retrieved info for Cordova, Alabama
# Retrieved info for Cottonwood, Alabama
# Retrieved info for County Line, Alabama
# Retrieved info for Courtland, Alabama
# Retrieved info for Cowarts, Alabama
# Retrieved info for Creola, Alabama
# Retrieved info for Crossville, Alabama
# Retrieved info for Cuba, Alabama
# Retrieved info for Cullman, Alabama
# Retrieved info for Cusseta, Alabama
# Retrieved info for Dadeville, Alabama
# Retrieved info for Daleville, Alabama
# Retrieved info for Daphne, Alabama
# Retrieved info for Dauphin Island, Alabama
# Retrieved info for Daviston, Alabama
# Retrieved info for Dayton, Alabama
# Retrieved info for Deatsville, Alabama
# Retrieved info for Decatur, Alabama
# Retrieved info for Demopolis, Alabama
# Retrieved info for Detroit, Alabama
# Retrieved info for Dodge City, Alabama
# Retrieved info for Dora, Alabama
# Retrieved info for Dothan, Alabama
# Retrieved info for Double Springs, Alabama
# Retrieved info for Douglas, Alabama
# Retrieved info for Dozier, Alabama
# Retrieved info for Dutton, Alabama
# Retrieved info for East Brewton, Alabama
# Retrieved info for Eclectic, Alabama
# Retrieved info for Edwardsville, Alabama
# Retrieved info for Elba, Alabama
# Retrieved info for Elberta, Alabama
# Retrieved info for Eldridge, Alabama
# Retrieved info for Elkmont, Alabama
# Retrieved info for Elmore, Alabama
# Retrieved info for Emelle, Alabama
# Retrieved info for Enterprise, Alabama
# Retrieved info for Epes, Alabama
# Retrieved info for Ethelsville, Alabama
# Retrieved info for Eufaula, Alabama
# Retrieved info for Eutaw, Alabama
# Retrieved info for Eva, Alabama
# Retrieved info for Evergreen, Conecuh County, Alabama
# Retrieved info for Excel, Alabama
# Retrieved info for Fairfield, Alabama
# Retrieved info for Fairhope, Alabama
# Retrieved info for Fairview, Alabama
# Retrieved info for Falkville, Alabama
# Retrieved info for Faunsdale, Alabama
# Retrieved info for Fayette, Alabama
# Retrieved info for Five Points, Alabama
# Retrieved info for Flomaton, Alabama
# Retrieved info for Florala, Alabama
# Retrieved info for Florence, Alabama
# Retrieved info for Foley, Alabama
# Retrieved info for Forkland, Alabama
# Retrieved info for Fort Deposit, Alabama
# Retrieved info for Fort Payne, Alabama
# Retrieved info for Franklin, Alabama
# Retrieved info for Frisco City, Alabama
# Retrieved info for Fruithurst, Alabama
# Retrieved info for Fulton, Alabama
# Retrieved info for Fultondale, Alabama
# Retrieved info for Fyffe, Alabama
# Retrieved info for Gadsden, Alabama
# Retrieved info for Gainesville, Alabama
# Retrieved info for Gantt, Alabama
# Retrieved info for Garden City, Alabama
# Retrieved info for Gardendale, Alabama
# Retrieved info for Gaylesville, Alabama
# Retrieved info for Geiger, Alabama
# Retrieved info for Geneva, Alabama
# Retrieved info for Georgiana, Alabama
# Retrieved info for Geraldine, Alabama
# Retrieved info for Gilbertown, Alabama
# Retrieved info for Glen Allen, Alabama
# Retrieved info for Glencoe, Alabama
# Retrieved info for Glenwood, Alabama
# Retrieved info for Goldville, Alabama
# Retrieved info for Good Hope, Alabama
# Retrieved info for Goodwater, Alabama
# Retrieved info for Gordo, Alabama
# Retrieved info for Gordon, Alabama
# Retrieved info for Gordonville, Alabama
# Retrieved info for Goshen, Alabama
# Retrieved info for Grant, Alabama
# Retrieved info for Graysville, Alabama
# Retrieved info for Greensboro, Alabama
# Retrieved info for Greenville, Alabama
# Retrieved info for Grimes, Alabama
# Retrieved info for Grove Hill, Alabama
# Retrieved info for Guin, Alabama
# Retrieved info for Gulf Shores, Alabama
# Retrieved info for Guntersville, Alabama
# Retrieved info for Gurley, Alabama
# Retrieved info for Gu-Win, Alabama
# Retrieved info for Hackleburg, Alabama
# Retrieved info for Haleburg, Alabama
# Retrieved info for Haleyville, Alabama
# Retrieved info for Hamilton, Alabama
# Retrieved info for Hammondville, Alabama
# Retrieved info for Hanceville, Alabama
# Retrieved info for Harpersville, Alabama
# Retrieved info for Hartford, Alabama
# Retrieved info for Hartselle, Alabama
# Retrieved info for Hayden, Alabama
# Retrieved info for Hayneville, Alabama
# Retrieved info for Headland, Alabama
# Retrieved info for Heath, Alabama
# Retrieved info for Heflin, Alabama
# Retrieved info for Helena, Alabama
# Retrieved info for Henagar, Alabama
# Retrieved info for Highland Lake, Alabama
# Retrieved info for Hillsboro, Alabama
# Retrieved info for Hobson City, Alabama
# Retrieved info for Hodges, Alabama
# Retrieved info for Hokes Bluff, Alabama
# Retrieved info for Holly Pond, Alabama
# Retrieved info for Hollywood, Alabama
# Retrieved info for Homewood, Alabama
# Retrieved info for Hoover, Alabama
# Retrieved info for Horn Hill, Alabama
# Retrieved info for Hueytown, Alabama
# Retrieved info for Huntsville, Alabama
# Retrieved info for Hurtsboro, Alabama
# Retrieved info for Hytop, Alabama
# Retrieved info for Ider, Alabama
# Retrieved info for Indian Springs Village, Alabama
# Retrieved info for Irondale, Alabama
# Retrieved info for Jackson, Alabama
# Retrieved info for Jackson's Gap, Alabama
# Retrieved info for Jacksonville, Alabama
# Retrieved info for Jasper, Alabama
# Retrieved info for Jemison, Alabama
# Retrieved info for Kansas, Alabama
# Retrieved info for Kellyton, Alabama
# Retrieved info for Kennedy, Alabama
# Retrieved info for Killen, Alabama
# Retrieved info for Kimberly, Alabama
# Retrieved info for Kinsey, Alabama
# Retrieved info for Kinston, Alabama
# Retrieved info for LaFayette, Alabama
# Retrieved info for Lake View, Alabama
# Retrieved info for Lakeview, Alabama
# Retrieved info for Lanett, Alabama
# Retrieved info for Langston, Alabama
# Retrieved info for Leeds, Alabama
# Retrieved info for Leesburg, Alabama
# Retrieved info for Leighton, Alabama
# Retrieved info for Lester, Alabama
# Retrieved info for Level Plains, Alabama
# Retrieved info for Lexington, Alabama
# Retrieved info for Libertyville, Alabama
# Retrieved info for Lincoln, Alabama
# Retrieved info for Linden, Alabama
# Retrieved info for Lineville, Alabama
# Retrieved info for Lipscomb, Alabama
# Retrieved info for Lisman, Alabama
# Retrieved info for Littleville, Alabama
# Retrieved info for Livingston, Alabama
# Retrieved info for Loachapoka, Alabama
# Retrieved info for Lockhart, Alabama
# Retrieved info for Locust Fork, Alabama
# Retrieved info for Louisville, Alabama
# Retrieved info for Lowndesboro, Alabama
# Retrieved info for Loxley, Alabama
# Retrieved info for Luverne, Alabama
# Retrieved info for Lynn, Alabama
# Retrieved info for Madison, Alabama
# Retrieved info for Madrid, Alabama
# Retrieved info for Magnolia Springs, Alabama
# Retrieved info for Malvern, Alabama
# Retrieved info for Maplesville, Alabama
# Retrieved info for Margaret, Alabama
# Retrieved info for Marion, Alabama
# Retrieved info for Maytown, Alabama
# Retrieved info for McIntosh, Alabama
# Retrieved info for McKenzie, Alabama
# Retrieved info for McMullen, Alabama
# Retrieved info for Memphis, Alabama
# Retrieved info for Mentone, Alabama
# Retrieved info for Midfield, Alabama
# Retrieved info for Midland City, Alabama
# Retrieved info for Midway, Alabama
# Retrieved info for Millbrook, Alabama
# Retrieved info for Millport, Alabama
# Retrieved info for Millry, Alabama
# Retrieved info for Mobile, Alabama
# Retrieved info for Monroeville, Alabama
# Retrieved info for Montevallo, Alabama
# Retrieved info for Montgomery, Alabama
# Retrieved info for Moody, Alabama
# Retrieved info for Mooresville, Alabama
# Retrieved info for Morris, Alabama
# Retrieved info for Mosses, Alabama
# Retrieved info for Moulton, Alabama
# Retrieved info for Moundville, Alabama
# Retrieved info for Mount Vernon, Alabama
# Retrieved info for Mountain Brook, Alabama
# Retrieved info for Mulga, Alabama
# Retrieved info for Munford, Alabama
# Retrieved info for Muscle Shoals, Alabama
# Retrieved info for Myrtlewood, Alabama
# Retrieved info for Napier Field, Alabama
# Retrieved info for Natural Bridge, Alabama
# Retrieved info for Nauvoo, Alabama
# Retrieved info for Nectar, Alabama
# Retrieved info for Needham, Alabama
# Retrieved info for New Brockton, Alabama
# Retrieved info for New Hope, Alabama
# Retrieved info for New Site, Alabama
# Retrieved info for Newbern, Alabama
# Retrieved info for Newton, Alabama
# Retrieved info for Newville, Alabama
# Retrieved info for North Courtland, Alabama
# Retrieved info for North Johns, Alabama
# Retrieved info for Northport, Alabama
# Retrieved info for Notasulga, Alabama
# Retrieved info for Oak Grove, Alabama
# Retrieved info for Oak Hill, Alabama
# Retrieved info for Oakman, Alabama
# Retrieved info for Odenville, Alabama
# Retrieved info for Ohatchee, Alabama
# Retrieved info for Oneonta, Alabama
# Retrieved info for Onycha, Alabama
# Retrieved info for Opelika, Alabama
# Retrieved info for Opp, Alabama
# Retrieved info for Orange Beach, Alabama
# Retrieved info for Orrville, Alabama
# Retrieved info for Owens Cross Roads, Alabama
# Retrieved info for Oxford, Alabama
# Retrieved info for Ozark, Alabama
# Retrieved info for Paint Rock, Alabama
# Retrieved info for Parrish, Alabama
# Retrieved info for Pelham, Alabama
# Retrieved info for Pell City, Alabama
# Retrieved info for Pennington, Alabama
# Retrieved info for Perdido Beach, Alabama
# Retrieved info for Petrey, Alabama
# Retrieved info for Phenix City, Alabama
# Retrieved info for Phil Campbell, Alabama
# Retrieved info for Pickensville, Alabama
# Retrieved info for Piedmont, Alabama
# Retrieved info for Pike Road, Alabama
# Retrieved info for Pinckard, Alabama
# Retrieved info for Pine Apple, Alabama
# Retrieved info for Pine Hill, Alabama
# Retrieved info for Pine Ridge, Alabama
# Retrieved info for Pinson, Alabama
# Retrieved info for Pisgah, Alabama
# Retrieved info for Pleasant Grove, Alabama
# Retrieved info for Pleasant Groves, Alabama
# Retrieved info for Pollard, Alabama
# Retrieved info for Powell, Alabama
# Retrieved info for Prattville, Alabama
# Retrieved info for Priceville, Alabama
# Retrieved info for Prichard, Alabama
# Retrieved info for Providence, Alabama
# Retrieved info for Ragland, Alabama
# Retrieved info for Rainbow City, Alabama
# Retrieved info for Rainsville, Alabama
# Retrieved info for Ranburne, Alabama
# Retrieved info for Red Bay, Alabama
# Retrieved info for Red Level, Alabama
# Retrieved info for Reece City, Alabama
# Retrieved info for Reform, Alabama
# Retrieved info for Rehobeth, Alabama
# Retrieved info for Repton, Alabama
# Retrieved info for Ridgeville, Alabama
# Retrieved info for River Falls, Alabama
# Retrieved info for Riverside, Alabama
# Retrieved info for Riverview, Alabama
# Retrieved info for Roanoke, Alabama
# Retrieved info for Robertsdale, Alabama
# Retrieved info for Rockford, Alabama
# Retrieved info for Rogersville, Alabama
# Retrieved info for Rosa, Alabama
# Retrieved info for Russellville, Alabama
# Retrieved info for Rutledge, Alabama
# Retrieved info for St. Florian, Alabama
# Retrieved info for Samson, Alabama
# Retrieved info for Sand Rock, Alabama
# Retrieved info for Sanford, Alabama
# Retrieved info for Saraland, Alabama
# Retrieved info for Sardis City, Alabama
# Retrieved info for Satsuma, Alabama
# Retrieved info for Scottsboro, Alabama
# Retrieved info for Section, Alabama
# Retrieved info for Selma, Alabama
# Retrieved info for Sheffield, Alabama
# Retrieved info for Shiloh, DeKalb County, Alabama
# Retrieved info for Shorter, Alabama
# Retrieved info for Silas, Alabama
# Retrieved info for Silverhill, Alabama
# Retrieved info for Sipsey, Alabama
# Retrieved info for Skyline, Alabama
# Retrieved info for Slocomb, Alabama
# Retrieved info for Smiths Station, Alabama
# Retrieved info for Snead, Alabama
# Retrieved info for Somerville, Alabama
# Retrieved info for South Vinemont, Alabama
# Retrieved info for Southside, Alabama
# Retrieved info for Spanish Fort, Alabama
# Retrieved info for Springville, Alabama
# Retrieved info for Steele, Alabama
# Retrieved info for Stevenson, Alabama
# Retrieved info for Sulligent, Alabama
# Retrieved info for Sumiton, Alabama
# Retrieved info for Summerdale, Alabama
# Retrieved info for Susan Moore, Alabama
# Retrieved info for Sweet Water, Alabama
# Retrieved info for Sylacauga, Alabama
# Retrieved info for Sylvan Springs, Alabama
# Retrieved info for Sylvania, Alabama
# Retrieved info for Talladega Springs, Alabama
# Retrieved info for Talladega, Alabama
# Retrieved info for Tallassee, Alabama
# Retrieved info for Tarrant, Alabama
# Retrieved info for Taylor, Alabama
# Retrieved info for Thomaston, Alabama
# Retrieved info for Thomasville, Alabama
# Retrieved info for Thorsby, Alabama
# Retrieved info for Town Creek, Alabama
# Retrieved info for Toxey, Alabama
# Retrieved info for Trafford, Alabama
# Retrieved info for Triana, Alabama
# Retrieved info for Trinity, Alabama
# Retrieved info for Troy, Alabama
# Retrieved info for Trussville, Alabama
# Retrieved info for Tuscaloosa, Alabama
# Retrieved info for Tuscumbia, Alabama
# Retrieved info for Tuskegee, Alabama
# Retrieved info for Twin, Alabama
# Retrieved info for Union Grove, Alabama
# Retrieved info for Union Springs, Alabama
# Retrieved info for Union, Alabama
# Retrieved info for Uniontown, Alabama
# Retrieved info for Valley, Alabama
# Retrieved info for Valley Grande, Alabama
# Retrieved info for Valley Head, Alabama
# Retrieved info for Vance, Alabama
# Retrieved info for Vernon, Alabama
# Retrieved info for Vestavia Hills, Alabama
# Retrieved info for Vina, Alabama
# Retrieved info for Vincent, Alabama
# Retrieved info for Vredenburgh, Alabama
# Retrieved info for Wadley, Alabama
# Retrieved info for Waldo, Alabama
# Retrieved info for Walnut Grove, Alabama
# Retrieved info for Warrior, Alabama
# Retrieved info for Waterloo, Alabama
# Retrieved info for Waverly, Alabama
# Retrieved info for Weaver, Alabama
# Retrieved info for Webb, Alabama
# Retrieved info for Wedowee, Alabama
# Retrieved info for West Blocton, Alabama
# Retrieved info for West Jefferson, Alabama
# Retrieved info for West Point, Alabama
# Retrieved info for Westover, Alabama
# Retrieved info for Wetumpka, Alabama
# Retrieved info for White Hall, Alabama
# Retrieved info for Wilsonville, Alabama
# Retrieved info for Wilton, Alabama
# Retrieved info for Winfield, Alabama
# Retrieved info for Woodland, Alabama
# Retrieved info for Woodstock, Alabama
# Retrieved info for Woodville, Alabama
# Retrieved info for Yellow Bluff, Alabama
# Retrieved info for York, Alabama
# Retrieved info for Adak, Alaska
# Retrieved info for Akhiok, Alaska
# Retrieved info for Akiak, Alaska
# Retrieved info for Akutan, Alaska
# Retrieved info for Alakanuk, Alaska
# Retrieved info for Aleknagik, Alaska
# Retrieved info for Allakaket, Alaska
# Retrieved info for Ambler, Alaska
# Retrieved info for Anaktuvuk Pass, Alaska
# Retrieved info for Anchorage, Alaska
# Retrieved info for Anderson, Alaska
# Retrieved info for Angoon, Alaska
# Retrieved info for Aniak, Alaska
# Retrieved info for Anvik, Alaska
# Retrieved info for Atka, Alaska
# Retrieved info for Atqasuk, Alaska
# Retrieved info for Bethel, Alaska
# Retrieved info for Bettles, Alaska
# Retrieved info for Brevig Mission, Alaska
# Retrieved info for Buckland, Alaska
# Retrieved info for Chefornak, Alaska
# Retrieved info for Chevak, Alaska
# Retrieved info for Chignik, Alaska
# Retrieved info for Chuathbaluk, Alaska
# Retrieved info for Clark's Point, Alaska
# Retrieved info for Coffman Cove, Alaska
# Retrieved info for Cold Bay, Alaska
# Retrieved info for Cordova, Alaska
# Retrieved info for Craig, Alaska
# Retrieved info for Deering, Alaska
# Retrieved info for Delta Junction, Alaska
# Retrieved info for Dillingham, Alaska
# Retrieved info for Diomede, Alaska
# Retrieved info for Eagle, Alaska
# Retrieved info for Edna Bay, Alaska
# Retrieved info for Eek, Alaska
# Retrieved info for Egegik, Alaska
# Retrieved info for Ekwok, Alaska
# Retrieved info for Elim, Alaska
# Retrieved info for Emmonak, Alaska
# Retrieved info for Fairbanks, Alaska
# Retrieved info for False Pass, Alaska
# Retrieved info for Fort Yukon, Alaska
# Retrieved info for Galena, Alaska
# Retrieved info for Gambell, Alaska
# Retrieved info for Golovin, Alaska
# Retrieved info for Goodnews Bay, Alaska
# Retrieved info for Grayling, Alaska
# Retrieved info for Gustavus, Alaska
# Retrieved info for Holy Cross, Alaska
# Retrieved info for Homer, Alaska
# Retrieved info for Hoonah, Alaska
# Retrieved info for Hooper Bay, Alaska
# Retrieved info for Houston, Alaska
# Retrieved info for Hughes, Alaska
# Retrieved info for Huslia, Alaska
# Retrieved info for Hydaburg, Alaska
# Retrieved info for Juneau, Alaska
# Retrieved info for Kachemak, Alaska
# Retrieved info for Kake, Alaska
# Retrieved info for Kaktovik, Alaska
# Retrieved info for Kaltag, Alaska
# Retrieved info for Kasaan, Alaska
# Retrieved info for Kenai, Alaska
# Retrieved info for Ketchikan, Alaska
# Retrieved info for Kiana, Alaska
# Retrieved info for King Cove, Alaska
# Retrieved info for Kivalina, Alaska
# Retrieved info for Klawock, Alaska
# Retrieved info for Kobuk, Alaska
# Retrieved info for Kodiak, Alaska
# Retrieved info for Kotlik, Alaska
# Retrieved info for Kotzebue, Alaska
# Retrieved info for Koyuk, Alaska
# Retrieved info for Koyukuk, Alaska
# Retrieved info for Kupreanof, Alaska
# Retrieved info for Kwethluk, Alaska
# Retrieved info for Larsen Bay, Alaska
# Retrieved info for Lower Kalskag, Alaska
# Retrieved info for Manokotak, Alaska
# Retrieved info for Marshall, Alaska
# Retrieved info for McGrath, Alaska
# Retrieved info for Mekoryuk, Alaska
# Retrieved info for Mountain Village, Alaska
# Retrieved info for Napakiak, Alaska
# Retrieved info for Napaskiak, Alaska
# Retrieved info for Nenana, Alaska
# Retrieved info for New Stuyahok, Alaska
# Retrieved info for Newhalen, Alaska
# Retrieved info for Nightmute, Alaska
# Retrieved info for Nikolai, Alaska
# Retrieved info for Nome, Alaska
# Retrieved info for Nondalton, Alaska
# Retrieved info for Noorvik, Alaska
# Retrieved info for North Pole, Alaska
# Retrieved info for Nuiqsut, Alaska
# Retrieved info for Nulato, Alaska
# Retrieved info for Nunam Iqua, Alaska
# Retrieved info for Nunapitchuk, Alaska
# Retrieved info for Old Harbor, Alaska
# Retrieved info for Ouzinkie, Alaska
# Retrieved info for Palmer, Alaska
# Retrieved info for Pelican, Alaska
# Retrieved info for Pilot Point, Alaska
# Retrieved info for Pilot Station, Alaska
# Retrieved info for Platinum, Alaska
# Retrieved info for Point Hope, Alaska
# Retrieved info for Port Alexander, Alaska
# Retrieved info for Port Heiden, Alaska
# Retrieved info for Port Lions, Alaska
# Retrieved info for Quinhagak, Alaska
# Retrieved info for Ruby, Alaska
# Retrieved info for Russian Mission, Alaska
# Retrieved info for Saint Paul, Alaska
# Retrieved info for Sand Point, Alaska
# Retrieved info for Savoonga, Alaska
# Retrieved info for Saxman, Alaska
# Retrieved info for Scammon Bay, Alaska
# Retrieved info for Selawik, Alaska
# Retrieved info for Seldovia, Alaska
# Retrieved info for Seward, Alaska
# Retrieved info for Shageluk, Alaska
# Retrieved info for Shaktoolik, Alaska
# Retrieved info for Shishmaref, Alaska
# Retrieved info for Shungnak, Alaska
# Retrieved info for Sitka, Alaska
# Retrieved info for Soldotna, Alaska
# Retrieved info for St. George, Alaska
# Retrieved info for St. Mary's, Alaska
# Retrieved info for St. Michael, Alaska
# Retrieved info for Stebbins, Alaska
# Retrieved info for Tanana, Alaska
# Retrieved info for Teller, Alaska
# Retrieved info for Tenakee Springs, Alaska
# Retrieved info for Thorne Bay, Alaska
# Retrieved info for Togiak, Alaska
# Retrieved info for Toksook Bay, Alaska
# Retrieved info for Unalakleet, Alaska
# Retrieved info for Unalaska, Alaska
# Retrieved info for Upper Kalskag, Alaska
# Retrieved info for Utqiaġvik
# Retrieved info for Valdez, Alaska
# Retrieved info for Wainwright, Alaska
# Retrieved info for Wales, Alaska
# Retrieved info for Wasilla, Alaska
# Retrieved info for Whale Pass, Alaska
# Retrieved info for White Mountain, Alaska
# Retrieved info for Whittier, Alaska
# Retrieved info for Wrangell, Alaska
# Retrieved info for Apache Junction, Arizona
# Retrieved info for Avondale, Arizona
# Retrieved info for Benson, Arizona
# Retrieved info for Bisbee, Arizona
# Retrieved info for Buckeye, Arizona
# Retrieved info for Bullhead City, Arizona
# Retrieved info for Camp Verde, Arizona
# Retrieved info for Carefree, Arizona
# Retrieved info for Casa Grande, Arizona
# Retrieved info for Cave Creek, Arizona
# Retrieved info for Chandler, Arizona
# Retrieved info for Chino Valley, Arizona
# Retrieved info for Clarkdale, Arizona
# Retrieved info for Clifton, Arizona
# Retrieved info for Colorado City, Arizona
# Retrieved info for Coolidge, Arizona
# Retrieved info for Cottonwood, Arizona
# Retrieved info for Dewey-Humboldt, Arizona
# Retrieved info for Douglas, Arizona
# Retrieved info for Duncan, Arizona
# Retrieved info for Eagar, Arizona
# Retrieved info for El Mirage, Arizona
# Retrieved info for Eloy, Arizona
# Retrieved info for Flagstaff, Arizona
# Retrieved info for Florence, Arizona
# Retrieved info for Fountain Hills, Arizona
# Retrieved info for Fredonia, Arizona
# Retrieved info for Gila Bend, Arizona
# Retrieved info for Gilbert, Arizona
# Retrieved info for Glendale, Arizona
# Retrieved info for Globe, Arizona
# Retrieved info for Goodyear, Arizona
# Retrieved info for Guadalupe, Arizona
# Retrieved info for Hayden, Arizona
# Retrieved info for Holbrook, Arizona
# Retrieved info for Huachuca City, Arizona
# Retrieved info for Jerome, Arizona
# Retrieved info for Kearny, Arizona
# Retrieved info for Kingman, Arizona
# Retrieved info for Lake Havasu City, Arizona
# Retrieved info for Litchfield Park, Arizona
# Retrieved info for Mammoth, Arizona
# Retrieved info for Marana, Arizona
# Retrieved info for Maricopa, Arizona
# Retrieved info for Mesa, Arizona
# Retrieved info for Miami, Arizona
# Retrieved info for Nogales, Arizona
# Retrieved info for Oro Valley, Arizona
# Retrieved info for Page, Arizona
# Retrieved info for Paradise Valley, Arizona
# Retrieved info for Parker, Arizona
# Retrieved info for Patagonia, Arizona
# Retrieved info for Payson, Arizona
# Retrieved info for Peoria, Arizona
# Retrieved info for Phoenix, Arizona
# Retrieved info for Pima, Arizona
# Retrieved info for Pinetop-Lakeside, Arizona
# Retrieved info for Prescott, Arizona
# Retrieved info for Prescott Valley, Arizona
# Retrieved info for Quartzsite, Arizona
# Retrieved info for Queen Creek, Arizona
# Retrieved info for Safford, Arizona
# Retrieved info for Sahuarita, Arizona
# Retrieved info for San Luis, Arizona
# Retrieved info for Scottsdale, Arizona
# Retrieved info for Sedona, Arizona
# Retrieved info for Show Low, Arizona
# Retrieved info for Sierra Vista, Arizona
# Retrieved info for Snowflake, Arizona
# Retrieved info for Somerton, Arizona
# Retrieved info for South Tucson, Arizona
# Retrieved info for Springerville, Arizona
# Retrieved info for St. Johns, Arizona
# Retrieved info for Star Valley, Arizona
# Retrieved info for Superior, Arizona
# Retrieved info for Surprise, Arizona
# Retrieved info for Taylor, Arizona
# Retrieved info for Tempe, Arizona
# Retrieved info for Thatcher, Arizona
# Retrieved info for Tolleson, Arizona
# Retrieved info for Tombstone, Arizona
# Retrieved info for Tucson, Arizona
# Retrieved info for Tusayan, Arizona
# Retrieved info for Wellton, Arizona
# Retrieved info for Wickenburg, Arizona
# Retrieved info for Willcox, Arizona
# Retrieved info for Williams, Arizona
# Retrieved info for Winkelman, Arizona
# Retrieved info for Winslow, Arizona
# Retrieved info for Youngtown, Arizona
# Retrieved info for Yuma, Arizona
# Retrieved info for Adona, Arkansas
# Retrieved info for Alexander, Arkansas
# Retrieved info for Alicia, Arkansas
# Retrieved info for Allport, Arkansas
# Retrieved info for Alma, Arkansas
# Retrieved info for Almyra, Arkansas
# Retrieved info for Alpena, Arkansas
# Retrieved info for Altheimer, Arkansas
# Retrieved info for Altus, Arkansas
# Retrieved info for Amagon, Arkansas
# Retrieved info for Amity, Arkansas
# Retrieved info for Anthonyville, Arkansas
# Retrieved info for Antoine, Arkansas
# Retrieved info for Arkadelphia, Arkansas
# Retrieved info for Arkansas City, Arkansas
# Retrieved info for Ash Flat, Arkansas
# Retrieved info for Ashdown, Arkansas
# Retrieved info for Atkins, Arkansas
# Retrieved info for Aubrey, Arkansas
# Retrieved info for Augusta, Arkansas
# Retrieved info for Austin, Arkansas
# Retrieved info for Avoca, Arkansas
# Retrieved info for Bald Knob, Arkansas
# Retrieved info for Banks, Arkansas
# Retrieved info for Barling, Arkansas
# Retrieved info for Bassett, Arkansas
# Retrieved info for Batesville, Arkansas
# Retrieved info for Bauxite, Arkansas
# Retrieved info for Bay, Arkansas
# Retrieved info for Bearden, Arkansas
# Retrieved info for Beaver, Arkansas
# Retrieved info for Beebe, Arkansas
# Retrieved info for Beedeville, Arkansas
# Retrieved info for Bella Vista, Arkansas
# Retrieved info for Bellefonte, Arkansas
# Retrieved info for Belleville, Arkansas
# Retrieved info for Ben Lomond, Arkansas
# Retrieved info for Benton, Arkansas
# Retrieved info for Bentonville, Arkansas
# Retrieved info for Bergman, Arkansas
# Retrieved info for Berryville, Arkansas
# Retrieved info for Bethel Heights, Arkansas
# Retrieved info for Big Flat, Arkansas
# Retrieved info for Bigelow, Arkansas
# Retrieved info for Biggers, Arkansas
# Retrieved info for Birdsong, Arkansas
# Retrieved info for Black Oak, Arkansas
# Retrieved info for Black Rock, Arkansas
# Retrieved info for Black Springs, Arkansas
# Retrieved info for Blevins, Arkansas
# Retrieved info for Blue Eye, Arkansas
# Retrieved info for Blue Mountain, Arkansas
# Retrieved info for Bluff City, Arkansas
# Retrieved info for Blytheville, Arkansas
# Retrieved info for Bodcaw, Arkansas
# Retrieved info for Bonanza, Arkansas
# Retrieved info for Bono, Arkansas
# Retrieved info for Booneville, Arkansas
# Retrieved info for Bradford, Arkansas
# Retrieved info for Bradley, Arkansas
# Retrieved info for Branch, Arkansas
# Retrieved info for Briarcliff, Arkansas
# Retrieved info for Brinkley, Arkansas
# Retrieved info for Brookland, Arkansas
# Retrieved info for Bryant, Arkansas
# Retrieved info for Buckner, Arkansas
# Retrieved info for Bull Shoals, Arkansas
# Retrieved info for Burdette, Arkansas
# Retrieved info for Cabot, Arkansas
# Retrieved info for Caddo Valley, Arkansas
# Retrieved info for Caldwell, Arkansas
# Retrieved info for Cale, Arkansas
# Retrieved info for Calico Rock, Arkansas
# Retrieved info for Calion, Arkansas
# Retrieved info for Camden, Arkansas
# Retrieved info for Cammack Village, Arkansas
# Retrieved info for Campbell Station, Arkansas
# Retrieved info for Caraway, Arkansas
# Retrieved info for Carlisle, Arkansas
# Retrieved info for Carthage, Arkansas
# Retrieved info for Casa, Arkansas
# Retrieved info for Cash, Arkansas
# Retrieved info for Caulksville, Arkansas
# Retrieved info for Cave City, Arkansas
# Retrieved info for Cave Springs, Arkansas
# Retrieved info for Cedarville, Arkansas
# Retrieved info for Centerton, Arkansas
# Retrieved info for Central City, Arkansas
# Retrieved info for Charleston, Arkansas
# Retrieved info for Cherokee Village, Arkansas
# Retrieved info for Cherry Valley, Arkansas
# Retrieved info for Chester, Arkansas
# Retrieved info for Chidester, Arkansas
# Retrieved info for Clarendon, Arkansas
# Retrieved info for Clarkedale, Arkansas
# Retrieved info for Clarksville, Arkansas
# Retrieved info for Clinton, Arkansas
# Retrieved info for Coal Hill, Arkansas
# Retrieved info for Colt, Arkansas
# Retrieved info for Concord, Arkansas
# Retrieved info for Conway, Arkansas
# Retrieved info for Corinth, Arkansas
# Retrieved info for Corning, Arkansas
# Retrieved info for Cotter, Arkansas
# Retrieved info for Cotton Plant, Arkansas
# Retrieved info for Cove, Arkansas
# Retrieved info for Coy, Arkansas
# Retrieved info for Crawfordsville, Arkansas
# Retrieved info for Crossett, Arkansas
# Retrieved info for Cushman, Arkansas
# Retrieved info for Daisy, Arkansas
# Retrieved info for Damascus, Arkansas
# Retrieved info for Danville, Arkansas
# Retrieved info for Dardanelle, Arkansas
# Retrieved info for Datto, Arkansas
# Retrieved info for De Queen, Arkansas
# Retrieved info for DeValls Bluff, Arkansas
# Retrieved info for Decatur, Arkansas
# Retrieved info for Delaplaine, Arkansas
# ...
# Retrieved info for Piedmont, West Virginia
# Retrieved info for Elizabeth, West Virginia
# Retrieved info for White Hall, West Virginia
# Retrieved info for Cedar Grove, West Virginia
# Retrieved info for Middlebourne, West Virginia
# Retrieved info for Glasgow, West Virginia
# Retrieved info for Grant Town, West Virginia
# Retrieved info for Fort Gay, West Virginia
# Retrieved info for War, West Virginia
# Retrieved info for West Union, West Virginia
# Retrieved info for Triadelphia, West Virginia
# Retrieved info for Danville, West Virginia
# Retrieved info for Pineville, West Virginia
# Retrieved info for Beverly, West Virginia
# Retrieved info for Thomas, West Virginia
# Retrieved info for Davis, West Virginia
# Retrieved info for Ridgeley, West Virginia
# Retrieved info for Reedsville, West Virginia
# Retrieved info for Mill Creek, West Virginia
# Retrieved info for Gauley Bridge, West Virginia
# Retrieved info for Beech Bottom, West Virginia
# Retrieved info for Masontown, West Virginia
# Retrieved info for West Hamlin, West Virginia
# Retrieved info for Anmoore, West Virginia
# Retrieved info for Hartford City, West Virginia
# Retrieved info for Franklin, West Virginia
# Retrieved info for Cowen, West Virginia
# Retrieved info for Grantsville, West Virginia
# Retrieved info for Pratt, West Virginia
# Retrieved info for Clearview, West Virginia
# Retrieved info for Rowlesburg, West Virginia
# Retrieved info for Peterstown, West Virginia
# Retrieved info for West Milford, West Virginia
# Retrieved info for Capon Bridge, West Virginia
# Retrieved info for Union, West Virginia
# Retrieved info for Delbarton, West Virginia
# Retrieved info for Paw Paw, West Virginia
# Retrieved info for Jane Lew, West Virginia
# Retrieved info for Farmington, West Virginia
# Retrieved info for Matewan, West Virginia
# Retrieved info for Burnsville, West Virginia
# Retrieved info for West Logan, West Virginia
# Retrieved info for Bancroft, West Virginia
# Retrieved info for Clay, West Virginia
# Retrieved info for Junior, West Virginia
# Retrieved info for Fairview, West Virginia
# Retrieved info for Lost Creek, West Virginia
# Retrieved info for Windsor Heights, West Virginia
# Retrieved info for Pine Grove, West Virginia
# Retrieved info for Whitesville, West Virginia
# Retrieved info for Lester, West Virginia
# Retrieved info for Gilbert, West Virginia
# Retrieved info for Meadow Bridge, West Virginia
# Retrieved info for Mitchell Heights, West Virginia
# Retrieved info for Tunnelton, West Virginia
# Retrieved info for Flemington, West Virginia
# Retrieved info for Kermit, West Virginia
# Retrieved info for Hedgesville, West Virginia
# Retrieved info for Bramwell, West Virginia
# Retrieved info for Newburg, West Virginia
# Retrieved info for Iaeger, West Virginia
# Retrieved info for Valley Grove, West Virginia
# Retrieved info for Harpers Ferry, West Virginia
# Retrieved info for Wardensville, West Virginia
# Retrieved info for Albright, West Virginia
# Retrieved info for Flatwoods, West Virginia
# Retrieved info for Hundred, West Virginia
# Retrieved info for Durbin, West Virginia
# Retrieved info for Northfork, West Virginia
# Retrieved info for Ellenboro, West Virginia
# Retrieved info for Hillsboro, West Virginia
# Retrieved info for Henderson, West Virginia
# Retrieved info for Davy, West Virginia
# Retrieved info for Hendricks, West Virginia
# Retrieved info for Handley, West Virginia
# Retrieved info for Bradshaw, West Virginia
# Retrieved info for Quinwood, West Virginia
# Retrieved info for Hambleton, West Virginia
# Retrieved info for Elk Garden, West Virginia
# Retrieved info for Bayard, West Virginia
# Retrieved info for Womelsdorf (Coalton), West Virginia
# Retrieved info for Keystone, West Virginia
# Retrieved info for Worthington, West Virginia
# Retrieved info for Sand Fork, West Virginia
# Retrieved info for Anawalt, West Virginia
# Retrieved info for Cairo, West Virginia
# Retrieved info for Matoaka, West Virginia
# Retrieved info for Falling Spring, West Virginia
# Retrieved info for Huttonsville, West Virginia
# Retrieved info for Sylvester, West Virginia
# Retrieved info for Kimball, West Virginia
# Retrieved info for Reedy, West Virginia
# Retrieved info for Montrose, West Virginia
# Retrieved info for Brandonville, West Virginia
# Retrieved info for Oakvale, West Virginia
# Retrieved info for Rhodell, West Virginia
# Retrieved info for Leon, West Virginia
# Retrieved info for Pax, West Virginia
# Retrieved info for Pullman, West Virginia
# Retrieved info for Camden-on-Gauley, West Virginia
# Retrieved info for Blacksville, West Virginia
# Retrieved info for Smithfield, West Virginia
# Retrieved info for Friendly, West Virginia
# Retrieved info for Harman, West Virginia
# Retrieved info for Auburn, West Virginia
# Retrieved info for Bruceton Mills, West Virginia
# Retrieved info for Thurmond, West Virginia
# Retrieved info for County (United States)
# Retrieved info for Abbotsford, Wisconsin
# Retrieved info for Adams, Wisconsin
# Retrieved info for Algoma, Wisconsin
# Retrieved info for Alma, Wisconsin
# Retrieved info for Altoona, Wisconsin
# Retrieved info for Amery, Wisconsin
# Retrieved info for Antigo, Wisconsin
# Retrieved info for Appleton, Wisconsin
# Retrieved info for Arcadia, Wisconsin
# Retrieved info for Ashland, Wisconsin
# Retrieved info for Augusta, Wisconsin
# Retrieved info for Baraboo, Wisconsin
# Retrieved info for Barron, Wisconsin
# Retrieved info for Bayfield, Wisconsin
# Retrieved info for Beaver Dam, Wisconsin
# Retrieved info for Beloit, Wisconsin
# Retrieved info for Berlin, Wisconsin
# Retrieved info for Black River Falls, Wisconsin
# Retrieved info for Blair, Wisconsin
# Retrieved info for Bloomer, Wisconsin
# Retrieved info for Boscobel, Wisconsin
# Retrieved info for Brillion, Wisconsin
# Retrieved info for Brodhead, Wisconsin
# Retrieved info for Brookfield, Wisconsin
# Retrieved info for Buffalo City, Wisconsin
# Retrieved info for Burlington, Wisconsin
# Retrieved info for Cedarburg, Wisconsin
# Retrieved info for Chetek, Wisconsin
# Retrieved info for Chilton, Wisconsin
# Retrieved info for Chippewa Falls, Wisconsin
# Retrieved info for Clintonville, Wisconsin
# Retrieved info for Colby, Wisconsin
# Retrieved info for Columbus, Wisconsin
# Retrieved info for Cornell, Wisconsin
# Retrieved info for Crandon, Wisconsin
# Retrieved info for Cuba City, Wisconsin
# Retrieved info for Cudahy, Wisconsin
# Retrieved info for Cumberland, Wisconsin
# Retrieved info for Darlington, Wisconsin
# Retrieved info for Delafield, Wisconsin
# Retrieved info for Delavan, Wisconsin
# Retrieved info for De Pere, Wisconsin
# Retrieved info for Dodgeville, Wisconsin
# Retrieved info for Durand, Wisconsin
# Retrieved info for Eagle River, Wisconsin
# Retrieved info for Eau Claire, Wisconsin
# Retrieved info for Edgerton, Wisconsin
# Retrieved info for Elkhorn, Wisconsin
# Retrieved info for Elroy, Wisconsin
# Retrieved info for Evansville, Wisconsin
# Retrieved info for Fennimore, Wisconsin
# Retrieved info for Fitchburg, Wisconsin
# Retrieved info for Fond du Lac, Wisconsin
# Retrieved info for Fort Atkinson, Wisconsin
# Retrieved info for Fountain City, Wisconsin
# Retrieved info for Fox Lake, Wisconsin
# Retrieved info for Franklin, Milwaukee County, Wisconsin
# Retrieved info for Galesville, Wisconsin
# Retrieved info for Gillett, Wisconsin
# Retrieved info for Glendale, Wisconsin
# Retrieved info for Glenwood City, Wisconsin
# Retrieved info for Green Bay, Wisconsin
# Retrieved info for Green Lake, Wisconsin
# Retrieved info for Greenfield, Wisconsin
# Retrieved info for Greenwood, Wisconsin
# Retrieved info for Hartford, Wisconsin
# Retrieved info for Hayward, Wisconsin
# Retrieved info for Hillsboro, Wisconsin
# Retrieved info for Horicon, Wisconsin
# Retrieved info for Hudson, Wisconsin
# Retrieved info for Hurley, Wisconsin
# Retrieved info for Independence, Wisconsin
# Retrieved info for Janesville, Wisconsin
# Retrieved info for Jefferson, Wisconsin
# Retrieved info for Juneau, Wisconsin
# Retrieved info for Kaukauna, Wisconsin
# Retrieved info for Kenosha, Wisconsin
# Retrieved info for Kewaunee, Wisconsin
# Retrieved info for Kiel, Wisconsin
# Retrieved info for La Crosse, Wisconsin
# Retrieved info for Ladysmith, Wisconsin
# Retrieved info for Lake Geneva, Wisconsin
# Retrieved info for Lake Mills, Wisconsin
# Retrieved info for Lancaster, Wisconsin
# Retrieved info for Lodi, Wisconsin
# Retrieved info for Loyal, Wisconsin
# Retrieved info for Madison, Wisconsin
# Retrieved info for Manawa, Wisconsin
# Retrieved info for Manitowoc, Wisconsin
# Retrieved info for Marinette, Wisconsin
# Retrieved info for Marion, Wisconsin
# Retrieved info for Markesan, Wisconsin
# Retrieved info for Marshfield, Wisconsin
# Retrieved info for Mauston, Wisconsin
# Retrieved info for Mayville, Wisconsin
# Retrieved info for Medford, Wisconsin
# Retrieved info for Mellen, Wisconsin
# Retrieved info for Menasha, Wisconsin
# Retrieved info for Menomonie, Wisconsin
# Retrieved info for Mequon, Wisconsin
# Retrieved info for Merrill, Wisconsin
# Retrieved info for Middleton, Wisconsin
# Retrieved info for Milton, Wisconsin
# Retrieved info for Milwaukee
# Retrieved info for Mineral Point, Wisconsin
# Retrieved info for Mondovi, Wisconsin
# Retrieved info for Monona, Wisconsin
# Retrieved info for Monroe, Wisconsin
# Retrieved info for Montello, Wisconsin
# Retrieved info for Montreal, Wisconsin
# Retrieved info for Mosinee, Wisconsin
# Retrieved info for Muskego, Wisconsin
# Retrieved info for Neenah, Wisconsin
# Retrieved info for Neillsville, Wisconsin
# Retrieved info for Nekoosa, Wisconsin
# Retrieved info for New Berlin, Wisconsin
# Retrieved info for New Holstein, Wisconsin
# Retrieved info for New Lisbon, Wisconsin
# Retrieved info for New London, Wisconsin
# Retrieved info for New Richmond, Wisconsin
# Retrieved info for Niagara, Wisconsin
# Retrieved info for Oak Creek, Wisconsin
# Retrieved info for Oconomowoc, Wisconsin
# Retrieved info for Oconto, Wisconsin
# Retrieved info for Oconto Falls, Wisconsin
# Retrieved info for Omro, Wisconsin
# Retrieved info for Onalaska, Wisconsin
# Retrieved info for Oshkosh, Wisconsin
# Retrieved info for Osseo, Wisconsin
# Retrieved info for Owen, Wisconsin
# Retrieved info for Park Falls, Wisconsin
# Retrieved info for Peshtigo, Wisconsin
# Retrieved info for Pewaukee, Wisconsin
# Retrieved info for Phillips, Wisconsin
# Retrieved info for Pittsville, Wisconsin
# Retrieved info for Platteville, Wisconsin
# Retrieved info for Plymouth, Wisconsin
# Retrieved info for Port Washington, Wisconsin
# Retrieved info for Portage, Wisconsin
# Retrieved info for Prairie du Chien, Wisconsin
# Retrieved info for Prescott, Wisconsin
# Retrieved info for Princeton, Wisconsin
# Retrieved info for Racine, Wisconsin
# Retrieved info for Reedsburg, Wisconsin
# Retrieved info for Rhinelander, Wisconsin
# Retrieved info for Rice Lake, Wisconsin
# Retrieved info for Richland Center, Wisconsin
# Retrieved info for Ripon, Wisconsin
# Retrieved info for River Falls, Wisconsin
# Retrieved info for St. Croix Falls, Wisconsin
# Retrieved info for St. Francis, Wisconsin
# Retrieved info for Schofield, Wisconsin
# Retrieved info for Seymour, Wisconsin
# Retrieved info for Shawano, Wisconsin
# Retrieved info for Sheboygan, Wisconsin
# Retrieved info for Sheboygan Falls, Wisconsin
# Retrieved info for Shell Lake, Wisconsin
# Retrieved info for Shullsburg, Wisconsin
# Retrieved info for South Milwaukee, Wisconsin
# Retrieved info for Sparta, Wisconsin
# Retrieved info for Spooner, Wisconsin
# Retrieved info for Stanley, Wisconsin
# Retrieved info for Stevens Point, Wisconsin
# Retrieved info for Stoughton, Wisconsin
# Retrieved info for Sturgeon Bay, Wisconsin
# Retrieved info for Sun Prairie, Wisconsin
# Retrieved info for Superior, Wisconsin
# Retrieved info for Thorp, Wisconsin
# Retrieved info for Tomah, Wisconsin
# Retrieved info for Tomahawk, Wisconsin
# Retrieved info for Two Rivers, Wisconsin
# Retrieved info for Verona, Wisconsin
# Retrieved info for Viroqua, Wisconsin
# Retrieved info for Washburn, Wisconsin
# Retrieved info for Waterloo, Wisconsin
# Retrieved info for Watertown, Wisconsin
# Retrieved info for Waukesha, Wisconsin
# Retrieved info for Waupaca, Wisconsin
# Retrieved info for Waupun, Wisconsin
# Retrieved info for Wausau, Wisconsin
# Retrieved info for Wautoma, Wisconsin
# Retrieved info for Wauwatosa, Wisconsin
# Retrieved info for West Allis, Wisconsin
# Retrieved info for West Bend, Wisconsin
# Retrieved info for West Salem, Wisconsin
# Retrieved info for Westby, Wisconsin
# Retrieved info for Weyauwega, Wisconsin
# Retrieved info for Whitehall, Wisconsin
# Retrieved info for Whitewater, Wisconsin
# Retrieved info for Wisconsin Dells, Wisconsin
# Retrieved info for Wisconsin Rapids, Wisconsin
# Retrieved info for County (United States)
# Retrieved info for Afton, Wyoming
# Retrieved info for Albin, Wyoming
# Retrieved info for Alpine, Wyoming
# Retrieved info for Baggs, Wyoming
# Retrieved info for Bairoil, Wyoming
# Retrieved info for Bar Nunn, Wyoming
# Retrieved info for Basin, Wyoming
# Retrieved info for Bear River, Wyoming
# Retrieved info for Big Piney, Wyoming
# Retrieved info for Buffalo, Wyoming
# Retrieved info for Burlington, Wyoming
# Retrieved info for Burns, Wyoming
# Retrieved info for Byron, Wyoming
# Retrieved info for Casper, Wyoming
# Retrieved info for Cheyenne, Wyoming
# Retrieved info for Chugwater, Wyoming
# Retrieved info for Clearmont, Wyoming
# Retrieved info for Cody, Wyoming
# Retrieved info for Cokeville, Wyoming
# Retrieved info for Cowley, Wyoming
# Retrieved info for Dayton, Wyoming
# Retrieved info for Deaver, Wyoming
# Retrieved info for Diamondville, Wyoming
# Retrieved info for Dixon, Wyoming
# Retrieved info for Douglas, Wyoming
# Retrieved info for Dubois, Wyoming
# Retrieved info for East Thermopolis, Wyoming
# Retrieved info for Edgerton, Wyoming
# Retrieved info for Elk Mountain, Wyoming
# Retrieved info for Encampment, Wyoming
# Retrieved info for Evanston, Wyoming
# Retrieved info for Evansville, Wyoming
# Retrieved info for Fort Laramie, Wyoming
# Retrieved info for Frannie, Wyoming
# Retrieved info for Gillette, Wyoming
# Retrieved info for Glendo, Wyoming
# Retrieved info for Glenrock, Wyoming
# Retrieved info for Granger, Wyoming
# Retrieved info for Green River, Wyoming
# Retrieved info for Greybull, Wyoming
# Retrieved info for Guernsey, Wyoming
# Retrieved info for Hanna, Wyoming
# Retrieved info for Hartville, Wyoming
# Retrieved info for Hudson, Wyoming
# Retrieved info for Hulett, Wyoming
# Retrieved info for Jackson, Wyoming
# Retrieved info for Kaycee, Wyoming
# Retrieved info for Kemmerer, Wyoming
# Retrieved info for Kirby, Wyoming
# Retrieved info for La Barge, Wyoming
# Retrieved info for La Grange, Wyoming
# Retrieved info for Lander, Wyoming
# Retrieved info for Laramie, Wyoming
# Retrieved info for Lingle, Wyoming
# Retrieved info for Lost Springs, Wyoming
# Retrieved info for Lovell, Wyoming
# Retrieved info for Lusk, Wyoming
# Retrieved info for Lyman, Wyoming
# Retrieved info for Manderson, Wyoming
# Retrieved info for Manville, Wyoming
# Retrieved info for Marbleton, Wyoming
# Retrieved info for Medicine Bow, Wyoming
# Retrieved info for Meeteetse, Wyoming
# Retrieved info for Midwest, Wyoming
# Retrieved info for Mills, Wyoming
# Retrieved info for Moorcroft, Wyoming
# Retrieved info for Mountain View, Wyoming
# Retrieved info for Newcastle, Wyoming
# Retrieved info for Opal, Wyoming
# Retrieved info for Pavillion, Wyoming
# Retrieved info for Pine Bluffs, Wyoming
# Retrieved info for Pinedale, Wyoming
# Retrieved info for Pine Haven, Wyoming
# Retrieved info for Powell, Wyoming
# Retrieved info for Ranchester, Wyoming
# Retrieved info for Rawlins, Wyoming
# Retrieved info for Riverside, Wyoming
# Retrieved info for Riverton, Wyoming
# Retrieved info for Rock River, Wyoming
# Retrieved info for Rock Springs, Wyoming
# Retrieved info for Rolling Hills, Wyoming
# Retrieved info for Saratoga, Wyoming
# Retrieved info for Sheridan, Wyoming
# Retrieved info for Shoshoni, Wyoming
# Retrieved info for Sinclair, Wyoming
# Retrieved info for Star Valley Ranch, Wyoming
# Retrieved info for Sundance, Wyoming
# Retrieved info for Superior, Wyoming
# Retrieved info for Ten Sleep, Wyoming
# Retrieved info for Thayne, Wyoming
# Retrieved info for Thermopolis, Wyoming
# Retrieved info for Torrington, Wyoming
# Retrieved info for Upton, Wyoming
# Retrieved info for Van Tassell, Wyoming
# Retrieved info for Wamsutter, Wyoming
# Retrieved info for Wheatland, Wyoming
# Retrieved info for Worland, Wyoming
# Retrieved info for Wright, Wyoming
# Retrieved info for Yoder, Wyoming

# %%
#testing on artile title loaded correctly
print(f"Getting page info data for: {ARTICLE_TITLES[3]}")
info = request_pageinfo_per_article(ARTICLE_TITLES[3])
print(json.dumps(info,indent=4))
# Out:
# Getting page info data for: Addison, Alabama
# {
#     "batchcomplete": "",
#     "query": {
#         "pages": {
#             "105188": {
#                 "pageid": 105188,
#                 "ns": 0,
#                 "title": "Addison, Alabama",
#                 "contentmodel": "wikitext",
#                 "pagelanguage": "en",
#                 "pagelanguagehtmlcode": "en",
#                 "pagelanguagedir": "ltr",
#                 "touched": "2023-10-10T22:35:37Z",
#                 "lastrevid": 1168359898,
#                 "length": 13309
#             }
#         }
#     }
# }

# %% [markdown]
# ## Step 2: Getting Article Quality Predictions

# %%
#########
#
#    CONSTANTS
#

#    The current LiftWing ORES API endpoint and prediction model
#
API_ORES_LIFTWING_ENDPOINT = "https://api.wikimedia.org/service/lw/inference/v1/models/{model_name}:predict"
API_ORES_EN_QUALITY_MODEL = "enwiki-articlequality"

#
#    The throttling rate is a function of the Access token that you are granted when you request the token. The constants
#    come from dissecting the token and getting the rate limits from the granted token. An example of that is below.
#
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (60.0/5000.0)-API_LATENCY_ASSUMED


REQUEST_HEADER_TEMPLATE = {
    'User-Agent': "<{}>, University of Washington, MSDS DATA 512 - AUTUMN 2023",
    'Content-Type': 'application/json',
    'Authorization': "Bearer {}"
}

#
#    This is a template for the parameters that we need to supply in the headers of an API request
#
REQUEST_HEADER_PARAMS_TEMPLATE = {
    'email_address' : "april.gg@uw.edu",         
    'access_token'  : "eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.....bBAtWdUvYMqo3tzA8pDDsToqcyZuZ0jZUElC-PdBcfmHl3U_edqQNah1biobl-RzI_4a3jchvInRAXPrdeyQy39CC9AcO5iZHSUMdDHYlYxDFXImaOz6FZa4H9x7hnx9Vw-Ap2ZDKlbprFrdH2EjA3KfOgwhD1aWsipkpcDO630xBvT74BHX79e2Q9YIFG7CSzuUAm_Y1JocN7qrSRcMkjZad_A0KsgAZkfK9bWDWn2uULdibjZyRpg3Cx0bVSyWjPkvb_k-W5hcaQouZ_KyQYBaaS0thIGEHnxz17CfokGn5BaGGd-b3MAvKD-QpbPxRwHAhVEzRQNGKwgrDQE8Uzp0GD11RfihJo95ak_KBxmFAb0qnJtbDriICT0LOy1rdVxFaeTWAAtXwTmprAAOoBlx9xtwr2lBAlJgvKP4FOFcjN24Uwm4wTd6uU9NAXFzfSS_Ltih4-TyQiPEgDWi4I1qmK-5MNE-EnzqfivW1yf_O3n1bcq2UcbJVNpLDkvKFEiufD--KUiLSNCVii0oRetnj5qf2-J6UWlAfWtdMZi20wSMW5GRXxltTY9jm5qSGkgD74fxf72Gof6NEm0ticcX4U_PTMNs-BcM5KYFZyvysQhdfwN5ZEUInLsIDZVMGbD190RmGjbYoxGmoS3TL90emixZ3L8emVq3sS1E7DQ"
}

#creating article revisions dict
article_revid_file = 'C:/Users/april/Documents/Documents/MSDS/DATA512/HW2/us_cities_by_state_SEPT.2023.csv'

ARTICLE_REVISIONS = {}

with open(article_revid_file, mode='r', encoding='utf-8') as file:  # specify the appropriate encoding here
    csv_reader = csv.DictReader(file)
    for row in csv_reader:
        if row['revid']:  # Check if the 'revid' is not an empty string
            ARTICLE_REVISIONS[row['page_title']] = int(float(row['revid']))
        else:
            pass

#    This is a template of the data required as a payload when making a scoring request of the ORES model

ORES_REQUEST_DATA_TEMPLATE = {
    "lang":        "en",     # required that its english - we're scoring English Wikipedia revisions
    "rev_id":      "",       # this request requires a revision id
    "features":    True
}

# %%
#username and token are hidden
USERNAME = ""
ACCESS_TOKEN = ""

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_ores_score_per_article(article_revid = None, email_address=None, access_token=None,
                                   endpoint_url = API_ORES_LIFTWING_ENDPOINT, 
                                   model_name = API_ORES_EN_QUALITY_MODEL, 
                                   request_data = ORES_REQUEST_DATA_TEMPLATE, 
                                   header_format = REQUEST_HEADER_TEMPLATE, 
                                   header_params = REQUEST_HEADER_PARAMS_TEMPLATE):
    
    #    Make sure we have an article revision id, email and token
    #    This approach prioritizes the parameters passed in when making the call
    if article_revid:
        request_data['rev_id'] = article_revid
    if email_address:
        header_params['email_address'] = email_address
    if access_token:
        header_params['access_token'] = access_token
    
    #   Making a request requires a revision id - an email address - and the access token
    if not request_data['rev_id']:
        raise Exception("Must provide an article revision id (rev_id) to score articles")
    if not header_params['email_address']:
        raise Exception("Must provide an 'email_address' value")
    if not header_params['access_token']:
        raise Exception("Must provide an 'access_token' value")
    
    # Create the request URL with the specified model parameter - default is a article quality score request
    request_url = endpoint_url.format(model_name=model_name)
    
    # Create a compliant request header from the template and the supplied parameters
    headers = dict()
    for key in header_format.keys():
        if key == 'User-Agent':
            headers[key] = header_format[key].format(header_params['email_address'])


    # make the request
    try:
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.post(request_url, headers=headers, data=json.dumps(request_data))
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
import csv
import json

# Define the function to call request_ores_score_per_article and update the CSV file
def update_csv_with_ores_scores(csv_file_path, ARTICLE_REVISIONS):
    with open(csv_file_path, mode='r', newline='',encoding='utf-8') as file:
        csv_reader = csv.DictReader(file)
        rows = [row for row in csv_reader]

    for row in rows:
        page_title = row['page_title']
        if page_title in ARTICLE_REVISIONS:
            revid = ARTICLE_REVISIONS[page_title]
            score = request_ores_score_per_article(article_revid=revid,
                                                   email_address="april.gg@uw.edu",
                                                   access_token=ACCESS_TOKEN)
            if score:
                try:
                    article_quality_score = score['enwiki']['scores'][str(revid)]['articlequality']['score']['prediction']
                    row['article_quality_score'] = article_quality_score
                except KeyError:
                    print(f"No score found for article with revid {revid}")

    with open(csv_file_path, mode='w', newline='',encoding='utf-8') as file:
        fieldnames = rows[0].keys()
        csv_writer = csv.DictWriter(file, fieldnames=fieldnames)
        csv_writer.writeheader()
        csv_writer.writerows(rows)

# Call the function to update the CSV file
update_csv_with_ores_scores("C:/Users/april/Documents/Documents/MSDS/DATA512/HW2/us_cities_by_state_SEPT.2023.csv", ARTICLE_REVISIONS)

# %% [markdown]
# ## Step 3: Combining the Datasets

# %% [markdown]
# ### merging the region data

# %%
region_df = pd.read_excel("C:/Users/april/Documents/Documents/MSDS/DATA512/HW2/US States by Region - US Census Bureau.xlsx")
region_df.head()
# Out:
#       REGION     DIVISION          STATE
# 0  Northeast          NaN            NaN
# 1        NaN  New England            NaN
# 2        NaN          NaN    Connecticut
# 3        NaN          NaN          Maine
# 4        NaN          NaN  Massachusetts

# %%
#Backfill the blanks in region and division
region_df['REGION'] = region_df['REGION'].fillna(method='ffill')
region_df['DIVISION'] = region_df['DIVISION'].fillna(method='ffill')
region_df.head()
# Out:
#       REGION     DIVISION          STATE
# 0  Northeast          NaN            NaN
# 1  Northeast  New England            NaN
# 2  Northeast  New England    Connecticut
# 3  Northeast  New England          Maine
# 4  Northeast  New England  Massachusetts

# %%
#Deleting NA records and change the 'state' column name to get ready to merge
region_df=region_df.dropna().reset_index(drop=True)
region_df.rename(columns={'STATE': 'state'}, inplace=True)
region_df.head()
# Out:
#       REGION     DIVISION          state
# 0  Northeast  New England    Connecticut
# 1  Northeast  New England          Maine
# 2  Northeast  New England  Massachusetts
# 3  Northeast  New England  New Hampshire
# 4  Northeast  New England   Rhode Island

# %%
score_df = pd.read_csv("C:/Users/april/Documents/Documents/MSDS/DATA512/HW2/us_cities_by_state_SEPT.2023.csv")
score_df.head()
# Out:
#      state           page_title  \
# 0  Alabama   Abbeville, Alabama
# 1  Alabama  Adamsville, Alabama
# 2  Alabama     Addison, Alabama
# 3  Alabama       Akron, Alabama
# 4  Alabama   Alabaster, Alabama
#
#                                                  url         revid  \
# 0   https://en.wikipedia.org/wiki/Abbeville,_Alabama  1.171164e+09
# 1  https://en.wikipedia.org/wiki/Adamsville,_Alabama  1.177621e+09
# 2     https://en.wikipedia.org/wiki/Addison,_Alabama  1.168360e+09
# 3       https://en.wikipedia.org/wiki/Akron,_Alabama  1.165910e+09
# 4   https://en.wikipedia.org/wiki/Alabaster,_Alabama  1.179140e+09
#
#   article_quality_score
# 0                     C
# 1                     C
# 2                     C
# 3                    GA
# 4                     C

# %%
score_region = pd.merge(region_df,score_df, on=['state'])
score_region.head()
# Out:
#       REGION     DIVISION  state        page_title  \
# 0  Northeast  New England  Maine      Abbot, Maine
# 1  Northeast  New England  Maine      Acton, Maine
# 2  Northeast  New England  Maine    Addison, Maine
# 3  Northeast  New England  Maine     Albion, Maine
# 4  Northeast  New England  Maine  Alexander, Maine
#
#                                               url         revid  \
# 0      https://en.wikipedia.org/wiki/Abbot,_Maine  1.171169e+09
# 1      https://en.wikipedia.org/wiki/Acton,_Maine  1.175249e+09
# 2    https://en.wikipedia.org/wiki/Addison,_Maine  1.168360e+09
# 3     https://en.wikipedia.org/wiki/Albion,_Maine  1.165910e+09
# 4  https://en.wikipedia.org/wiki/Alexander,_Maine  1.170294e+09
#
#   article_quality_score
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %% [markdown]
# ### merging population data

# %%
population_df = pd.read_csv("C:/Users/april/Documents/Documents/MSDS/DATA512/HW2/NST-EST2022-ALLDATA.csv")
population_df.head()
# Out:
#    SUMLEV REGION DIVISION  STATE              NAME  ESTIMATESBASE2020  \
# 0      10      0        0      0     United States          331449520
# 1      20      1        0      0  Northeast Region           57609156
# 2      30      1        1      0       New England           15116206
# 3      30      1        2      0   Middle Atlantic           42492950
# 4      20      2        0      0    Midwest Region           68985537
#
#    POPESTIMATE2020  POPESTIMATE2021  POPESTIMATE2022  NPOPCHG_2020  ...  \
# 0        331511512        332031554        333287557         61992  ...
# 1         57448898         57259257         57040406       -160258  ...
# 2         15074473         15121745         15129548        -41733  ...
# 3         42374425         42137512         41910858       -118525  ...
# 4         68961043         68836505         68787595        -24494  ...
#
#    RDEATH2021  RDEATH2022  RNATURALCHG2021  RNATURALCHG2022  \
# 0   10.363828   10.350218         0.434073         0.736729
# 1    9.780142    9.868918         0.206629         0.511200
# 2    9.530598    9.887115        -0.310502        -0.206669
# 3    9.869304    9.862369         0.391400         0.769581
# 4   11.059195   11.169148        -0.207043        -0.125530
#
#    RINTERNATIONALMIG2021  RINTERNATIONALMIG2022  RDOMESTICMIG2021  \
# 0               1.133397               3.038912          0.000000
# 1               1.402708               3.752662         -4.855348
# 2               1.770752               4.655140          1.546021
# 3               1.271205               3.427836         -7.142565
# 4               0.802714               2.111084         -2.645374
#
#    RDOMESTICMIG2022  RNETMIG2021  RNETMIG2022
# 0          0.000000     1.133397     3.038912
# 1         -8.061896    -3.452640    -4.309234
# 2         -3.767839     3.316773     0.887301
# 3         -9.607444    -5.871360    -6.179608
# 4         -2.529339    -1.842660    -0.418255
#
# [5 rows x 45 columns]

# %%
#drop irrelevant columns and rename to get ready to merge
population_df = population_df[['NAME', 'POPESTIMATE2022']]
population_df = population_df.rename(columns={"NAME": "state", "POPESTIMATE2022": "population"})
population_df.head()
# Out:
#               state  population
# 0     United States   333287557
# 1  Northeast Region    57040406
# 2       New England    15129548
# 3   Middle Atlantic    41910858
# 4    Midwest Region    68787595

# %%
final_df = pd.merge(population_df,score_region, on=['state'])
final_df.head()
# Out:
#      state  population REGION            DIVISION           page_title  \
# 0  Alabama     5031362  South  East South Central   Abbeville, Alabama
# 1  Alabama     5031362  South  East South Central  Adamsville, Alabama
# 2  Alabama     5031362  South  East South Central     Addison, Alabama
# 3  Alabama     5031362  South  East South Central       Akron, Alabama
# 4  Alabama     5031362  South  East South Central   Alabaster, Alabama
#
#                                                  url         revid  \
# 0   https://en.wikipedia.org/wiki/Abbeville,_Alabama  1.171164e+09
# 1  https://en.wikipedia.org/wiki/Adamsville,_Alabama  1.177621e+09
# 2     https://en.wikipedia.org/wiki/Addison,_Alabama  1.168360e+09
# 3       https://en.wikipedia.org/wiki/Akron,_Alabama  1.165910e+09
# 4   https://en.wikipedia.org/wiki/Alabaster,_Alabama  1.179140e+09
#
#   article_quality_score
# 0                     C
# 1                     C
# 2                     C
# 3                    GA
# 4                     C

# %%
final_df.drop(['url','DIVISION'], axis=1, inplace=True)
df_final = df_final.rename(columns={'REGION': 'regional_division','page_title': 'article_title','revid':'revision_id','article_quality_score':'article_quality' })
final_df.to_csv('wp_scored_city_articles_by_state.csv', index=False)
